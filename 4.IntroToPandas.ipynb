# %%
import pandas as pd

# %%
import numpy as np

# %%
grades ={"Cemre":100,"Atıl":85,"Vic":50}

# %%
pd.Series(grades)
# Out:
# Cemre    100
# Atıl      85
# Vic       50
# dtype: int64

# %%
isim=["Cemre","Atıl","Vic"]
puan=[100,85,50]

# %%
pd.Series(isim)
# Out:
# 0    Cemre
# 1     Atıl
# 2      Vic
# dtype: object

# %%
pd.Series(puan)
# Out:
# 0    100
# 1     85
# 2     50
# dtype: int64

# %%
pd.Series(isim,puan)
# Out:
# 100    Cemre
# 85      Atıl
# 50       Vic
# dtype: object

# %%
pd.Series(puan,isim) #Yani Series çıktısı (data,index) şeklindedir
# Out:
# Cemre    100
# Atıl      85
# Vic       50
# dtype: int64

# %%
pd.Series(data=isim,index=puan) #bu şekildilirize data ve indexin yerlerini de belirtebiliriz
# Out:
# 100    Cemre
# 85      Atıl
# 50       Vic
# dtype: object

# %% [markdown]
# ### With Numpy

# %%
numpy_array = np.array([50,60,70,80])

# %%
pd.Series(numpy_array)
# Out:
# 0    50
# 1    60
# 2    70
# 3    80
# dtype: int64

# %% [markdown]
# ### Aritmetic

# %%
contest_result= pd.Series(data=[10,5,100], index=["Atıl","Cemre","Vic"])

# %%
contest_result2= pd.Series(data=[20,50,10],index=["Atıl","Cemre","Vic"])

# %%
contest_result["Atıl"]
# Out:
# np.int64(10)

# %%
contest_result2["Vic"]
# Out:
# np.int64(10)

# %%
final_result= contest_result + contest_result2

# %%
final_result
# Out:
# Atıl      30
# Cemre     55
# Vic      110
# dtype: int64

# %%
final_result= contest_result - contest_result2

# %%
final_result
# Out:
# Atıl    -10
# Cemre   -45
# Vic      90
# dtype: int64

# %%
final_result= contest_result * contest_result2

# %%
final_result
# Out:
# Atıl      200
# Cemre     250
# Vic      1000
# dtype: int64

# %%
differen_series= pd.Series(data=[100,15,39,50], index=["a","b","c","d"])

# %%
differen_series2= pd.Series(data=[10,25,98,40], index=["a","c","f","g"])

# %%
differen_series +differen_series2 #ortak dataların yeri nerede olursa olsun toplar, ortak olmayan datalara karşılık NaN(bilinmiyor) yazar
# Out:
# a    110.0
# b      NaN
# c     64.0
# d      NaN
# f      NaN
# g      NaN
# dtype: float64

# %%
#

# %%
import numpy as np

# %%
new_array= np.random.randint(1,100,20) # 1 den 100 e kadar 20 tane

# %%
new_array
# Out:
# array([ 3,  5,  9, 49, 66, 21, 71,  4, 98, 91, 63, 71, 50, 25, 61, 96, 60,
#        37,  5, 18], dtype=int32)

# %%
new_array >25
# Out:
# array([False, False, False,  True,  True, False,  True, False,  True,
#         True,  True,  True,  True, False,  True,  True,  True,  True,
#        False, False])

# %%
new_array[new_array >25]
# Out:
# array([49, 66, 71, 98, 91, 63, 71, 50, 61, 96, 60, 37], dtype=int32)

# %%
matrix = np.array([[10,20],[30,40],[50,60]])

# %%
matrix.transpose() #yerleri değiştirir
# Out:
# array([[10, 30, 50],
#        [20, 40, 60]])

# %%
random_array = np.random.random((6,1))

# %%
random_array
# Out:
# array([[0.1199778 ],
#        [0.3100265 ],
#        [0.56423956],
#        [0.15645827],
#        [0.94573107],
#        [0.25804491]])

# %%
random_array.reshape(2,3)#boyutunu şeklinayi değiştirir.
# Out:
# array([[0.1199778 , 0.3100265 , 0.56423956],
#        [0.15645827, 0.94573107, 0.25804491]])

# %% [markdown]
# ***Özel operatörler***

# %%
array1= np.array([10,20,30,45,100,150])

# %%
mean = array1.mean() #ortalama

# %%
print(mean)
# Out:
# 59.166666666666664

# %%
std= array1.std() #standart sapma

# %%
print(std)
# Out:
# 49.867881001257274

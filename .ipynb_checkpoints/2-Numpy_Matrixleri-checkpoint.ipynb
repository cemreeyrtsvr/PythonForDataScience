# %%
import numpy as np

# %%
my_matrix = [[5,10],[10,20]]

# %%
my_matrix[1]
# Out:
# [10, 20]

# %%
my_matrix[1][1]
# Out:
# 20

# %% [markdown]
# ***row * collum (satır * kolon)***

# %%
numpy_matrix = np.array([[5,10],[20,30]])

# %%
numpy_matrix
# Out:
# array([[ 5, 10],
#        [20, 30]])

# %%
numpy_matrix+my_matrix
# Out:
# array([[10, 20],
#        [30, 50]])

# %%
third_array = np.array([2,50])

# %%
numpy_matrix + third_array
# Out:
# array([[ 7, 60],
#        [22, 80]])

# %%
numpy_matrix * 5
# Out:
# array([[ 25,  50],
#        [100, 150]])

# %% [markdown]
# ***Matrix çarpımları ve dot product***

# %%
my_matrix * numpy_matrix
# Out:
# array([[ 25, 100],
#        [200, 600]])

# %%
# dot product yapılması için birinci matrisin colluumu ile ikinci matrixin row sayısı eşit olunca yapılabilir.

# %%
third_array.shape
# Out:
# (2,)

# %%
numpy_matrix.shape
# Out:
# (2, 2)

# %%
first_matrix= np.array([[10,20,30],[40,50,60]])

# %%
first_matrix.shape
# Out:
# (2, 3)

# %%
second_array= np.array([[20],[30],[50]])

# %%
second_array.shape
# Out:
# (3, 1)

# %%
first_matrix.dot(second_array) #son dizi boyutu birincinin row u ikincinin colu şeklinde olur
# Out:
# array([[2300],
#        [5300]])

# %%
import numpy as np #çalışmazsa !pip install numpy yaz

# %%
myList= [10,20,30,40]

# %%
my_array=np.array(myList)

# %%
my_array
# Out:
# array([10, 20, 30, 40])

# %%
type(my_array)
# Out:
# numpy.ndarray

# %%
int(my_array.max())
# Out:
# 40

# %%
np.ones(5) #sadece birlerden oluşan dizi
# Out:
# array([1., 1., 1., 1., 1.])

# %%
np.zeros(5)#sadece sıfırlardan oluşan dizi
# Out:
# array([0., 0., 0., 0., 0.])

# %%
np.random.random_sample(5) #random sayılardan oluşan dizi
# Out:
# array([0.15917736, 0.82189422, 0.74504995, 0.75172422, 0.82805289])

# %% [markdown]
# ***Array Aritmetic***

# %%
myList= [15,25]
myList2=[10,18]

# %%
myList+myList2 # 2 dizide de aynı sayıda değer olmalı ya da 1 tanesi tek elemanlı olmalı , 2 elemanlı diziyle 5 elemanlı dizi toplanmaz
# Out:
# [15, 25, 10, 18]

# %%
myArray1=np.array(myList)
myArray2=np.array(myList2)

# %%
myArray1+myArray2
# Out:
# array([25, 43])

# %%
myArray1 * 5
# Out:
# array([ 75, 125])

# %%
myArray1.max()
# Out:
# np.int64(25)

# %%
myArray1.min()
# Out:
# np.int64(15)

# %%
myArray1 .sum()
# Out:
# np.int64(40)

# %% [markdown]
# ***Arange and İndex (liste ile aynıdır)***

# %%
liste= list(range(0,11,2))

# %%
liste
# Out:
# [0, 2, 4, 6, 8, 10]

# %%
np_array=np.arange(0,30,3)

# %%
np_array
# Out:
# array([ 0,  3,  6,  9, 12, 15, 18, 21, 24, 27])

# %%
np_array[0]
# Out:
# np.int64(0)

# %%
np_array[-1]
# Out:
# np.int64(27)

# %%
np_array[::-1]
# Out:
# array([27, 24, 21, 18, 15, 12,  9,  6,  3,  0])

# %%
np.random.randn(4)
# Out:
# array([-0.71842234, -0.55990453, -0.39499633, -0.97739487])

# %%
np.random.randn(4,4)
# Out:
# array([[ 0.61143581,  0.37827718, -0.38843489, -1.17170044],
#        [-0.52161624,  0.05768181, -0.68253753,  0.32152482],
#        [ 1.07309232, -1.37037259,  0.06496876,  1.7204904 ],
#        [-0.01880956,  0.95315344, -1.82849306,  0.00456039]])

# %%
np.random.randint(0,300,5)
# Out:
# array([233, 174, 255, 147, 281], dtype=int32)
